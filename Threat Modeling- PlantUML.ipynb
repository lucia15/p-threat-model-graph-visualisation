# %%
#pip install iplantuml

# %%
import iplantuml

# %%
# %%plantuml
#
# @startuml
#
# Boy -> Girl  :Loves
#
# Girl --> Boy :Whatever
#
# @enduml

# %%
# %%plantuml
#
# @startuml
#
# 'Setting the Icon URLs for the different Libraries
# !define ICONURL https://raw.githubusercontent.com/tupadr3/plantuml-icon-font-sprites/v2.2.0
# !define AzurePuml https://raw.githubusercontent.com/RicardoNiepel/Azure-PlantUML/release/2-1/dist
# !define KubernetesPuml https://raw.githubusercontent.com/dcasati/kubernetes-PlantUML/master/dist
#
# 'importing the C4 Model
# !include <C4/C4_Context.puml>
# !includeurl ICONURL/common.puml
#
# ' Importing the AWS icons
# !include <awslib/AWSCommon>
# !include <awslib/AWSSimplified.puml>
# !include <awslib/Database/all.puml>
#
# ' Importing the Azure icons
# !includeurl AzurePuml/AzureCommon.puml
# !includeurl AzurePuml/Containers/all.puml
#
# ' Importing the Kubernetes icons
# !includeurl KubernetesPuml/kubernetes_Context.puml
# !includeurl KubernetesPuml/kubernetes_Simplified.puml
# !includeurl KubernetesPuml/OSS/KubernetesApi.puml
#
# ' Importing the Font Awesome icons
# !includeurl ICONURL/common.puml
# !includeurl ICONURL/font-awesome-5/user_cog.puml
#
# 'creating C4 Model entities
#
# System_Ext(extAlias,              "External System") #Red
# AzureKubernetesService(container, "Containers", "Secure")
# KubernetesApi(kubernetes,         "\nKubernetes Cluster" ," ")
# FA5_USER_COG(administrator,        Administrator) #Green
#
# Boundary(boundaryAlias,           "Secure System"){
#   Person(personAlias,             "Person")
#   System(systemAlias,             "System")
#   Aurora(db,                      "Database", "")
# }
#
# personAlias         -right->     systemAlias  :Login
# extAlias            -up->        systemAlias  :Attacks
# systemAlias         -up->        db
# systemAlias         ->           container
# container           -down->      kubernetes
# administrator       -->          kubernetes
#
# @enduml
